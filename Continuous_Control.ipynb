# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
# env = UnityEnvironment(file_name='Reacher.app')

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# # get the default brain
# brain_name = env.brain_names[0]
# brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# # reset the environment
# env_info = env.reset(train_mode=True)[brain_name]

# # number of agents
# num_agents = len(env_info.agents)
# print('Number of agents:', num_agents)

# # size of each action
# action_size = brain.vector_action_space_size
# print('Size of each action:', action_size)

# # examine the state space 
# states = env_info.vector_observations
# state_size = states.shape[1]
# print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
# print('The state for the first agent looks like:', states[0])

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import *

# %% [markdown]
# # Train the Agent with DDPG version 1

# %%
# env = UnityEnvironment(file_name='Reacher_v1.app')
# brain_name = env.brain_names[0]
# brain = env.brains[brain_name]
# env_info = env.reset(train_mode=True)[brain_name]

# # number of agents
# num_agents = len(env_info.agents)
# print('Number of agents:', num_agents)

# # size of each action
# action_size = brain.vector_action_space_size
# print('Size of each action:', action_size)

# # examine the state space 
# states = env_info.vector_observations
# state_size = states.shape[1]
# print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
# print('The state for the first agent looks like:', states[0])

# %%
# def ddpg(n_episodes=1000, max_t=500, print_every=100):
#     scores_deque = deque(maxlen=100)
#     scores = [0]
#     agent = Agent(state_size=33, action_size=4, random_seed=2)
#     env_info = env.reset(train_mode=True)[brain_name]
#     state = env_info.vector_observations[0]
#     score = 0        
#     for i_episode in range(1, n_episodes+1):
#         state = env_info.vector_observations[0]
#         agent.reset()
#         score=0
#         for t in range(max_t):
#             action = agent.act(state)
#             env_info = env.step(action)[brain_name]
#             next_state = env_info.vector_observations[0] 
#             reward = env_info.rewards[0]
#             done = env_info.local_done[0]
#             agent.step(state, action, reward, next_state, done)
#             state = next_state
#             score += reward
#             if done:
#                 break 
#         scores_deque.append(score)
#         scores.append(score)
        
#         print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)), end="")
#         torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
#         torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
#         if np.mean(scores_deque) > 30:
#             print("\rsolved")
#             torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
#             torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
#             return scores
#         if i_episode % print_every == 0:
#             print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            
#     return scores

# %%
# scores = ddpg(print_every=10)

# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.plot(np.arange(1, len(scores)+1), scores)
# plt.ylabel('Score')
# plt.xlabel('Episode #')
# plt.show()

# %% [markdown]
# # Train the Agent with DDPG version 2

# %%
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

env = UnityEnvironment(file_name='Reacher_v2.app')

# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %%
from ddpg_agent import *

# %%
def ddpg2(n_episodes=2000, max_t=1000, print_every=100):
    env_info = env.reset(train_mode=True)[brain_name]
    scores_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)
    agent = Agent(state_size=state_size, action_size=action_size, random_seed=1, num_agents=num_agents)
    scores_global = []
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations 
        agent.reset()
        scores = np.zeros(num_agents)
        for t in range(max_t):
            agent.noise.reset()
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = env_info.local_done
            
            agent.step(states, actions, rewards, next_states, dones, t)
            states = next_states 
            scores += rewards
            if (np.any(dones)):
                break

        score = np.mean(scores)
        scores_deque.append(score)
        avg_score = np.mean(scores_deque)
        scores_global.append(score)
        
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, avg_score, score), end="")
        torch.save(agent.actor_local.state_dict(), 'checkpoint_actor2.pth')
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic2.pth')
        if avg_score > 30:
            print("\rsolved")
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor2.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic2.pth')
            return scores_global
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, avg_score, score))
            
    return scores_global

# %%
scores = ddpg2(print_every=1)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# /Users/yuki/dri_p2/ddpg_agent.py:120: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.critic_local.parameters(), 1)
# Episode 1	Average Score: 0.15	Score: 0.15
# Episode 2	Average Score: 0.14	Score: 0.13
# Episode 3	Average Score: 0.18	Score: 0.27
# Episode 4	Average Score: 0.42	Score: 1.14
# Episode 5	Average Score: 0.60	Score: 1.30
# Episode 6	Average Score: 0.67	Score: 1.03
# Episode 7	Average Score: 0.74	Score: 1.18
# Episode 8	Average Score: 0.78	Score: 1.04
# Episode 9	Average Score: 0.87	Score: 1.55
# Episode 10	Average Score: 0.93	Score: 1.45
# Episode 11	Average Score: 0.95	Score: 1.20
# Episode 12	Average Score: 0.99	Score: 1.46
# Episode 13	Average Score: 1.03	Score: 1.53
# Episode 14	Average Score: 1.04	Score: 1.09
# Episode 15	Average Score: 1.04	Score: 1.12
# Episode 16	Average Score: 1.03	Score: 0.77
# Episode 17	Average Score: 1.01	Score: 0.76
# Episode 18	Average Score: 1.00	Score: 0.86
# Episode 19	Average Score: 1.02	Score: 1.39
# Episode 20	Average Score: 1.05	Score: 1.49
# Episode 21	Average Score: 1.08	Score: 1.77
# Episode 22	Average Score: 1.10	Score: 1.49
# Episode 23	Average Score: 1.11	Score: 1.46
# Episode 24	Average Score: 1.13	Score: 1.44
# Episode 25	Average Score: 1.16	Score: 1.94
# Episode 26	Average Score: 1.19	Score: 1.92
# Episode 27	Average Score: 1.21	Score: 1.63
# Episode 28	Average Score: 1.24	Score: 2.17
# Episode 29	Average Score: 1.28	Score: 2.29
# Episode 30	Average Score: 1.33	Score: 2.83
# Episode 31	Average Score: 1.37	Score: 2.62
# Episode 32	Average Score: 1.42	Score: 2.88
# Episode 33	Average Score: 1.44	Score: 2.07
# Episode 34	Average Score: 1.47	Score: 2.52
# Episode 35	Average Score: 1.51	Score: 2.79
# Episode 36	Average Score: 1.56	Score: 3.48
# Episode 37	Average Score: 1.60	Score: 2.92
# Episode 38	Average Score: 1.68	Score: 4.63
# Episode 39	Average Score: 1.73	Score: 3.75
# Episode 40	Average Score: 1.78	Score: 3.65
# Episode 41	Average Score: 1.83	Score: 4.04
# Episode 42	Average Score: 1.88	Score: 3.73
# Episode 43	Average Score: 1.94	Score: 4.44
# Episode 44	Average Score: 2.00	Score: 4.43
# Episode 45	Average Score: 2.04	Score: 3.78
# Episode 46	Average Score: 2.09	Score: 4.64
# Episode 47	Average Score: 2.15	Score: 4.70
# Episode 48	Average Score: 2.21	Score: 5.31
# Episode 49	Average Score: 2.30	Score: 6.24
# Episode 50	Average Score: 2.36	Score: 5.48
# Episode 51	Average Score: 2.43	Score: 5.72
# Episode 52	Average Score: 2.49	Score: 5.62
# Episode 53	Average Score: 2.57	Score: 6.79
# Episode 54	Average Score: 2.66	Score: 7.73
# Episode 55	Average Score: 2.75	Score: 7.62
# Episode 56	Average Score: 2.85	Score: 8.04
# Episode 57	Average Score: 2.92	Score: 7.12
# Episode 58	Average Score: 2.99	Score: 6.66
# Episode 59	Average Score: 3.09	Score: 8.74
# Episode 60	Average Score: 3.17	Score: 7.96
# Episode 61	Average Score: 3.24	Score: 7.36
# Episode 62	Average Score: 3.32	Score: 8.50
# Episode 63	Average Score: 3.41	Score: 8.68
# Episode 64	Average Score: 3.49	Score: 9.12
# Episode 65	Average Score: 3.57	Score: 8.29
# Episode 66	Average Score: 3.64	Score: 8.55
# Episode 67	Average Score: 3.72	Score: 9.01
# Episode 68	Average Score: 3.82	Score: 10.01
# Episode 69	Average Score: 3.90	Score: 9.89
# Episode 70	Average Score: 4.01	Score: 11.00
# Episode 71	Average Score: 4.08	Score: 9.50
# Episode 72	Average Score: 4.14	Score: 8.54
# Episode 73	Average Score: 4.21	Score: 8.99
# Episode 74	Average Score: 4.29	Score: 10.32
# Episode 75	Average Score: 4.38	Score: 10.83
# Episode 76	Average Score: 4.45	Score: 9.63
# Episode 77	Average Score: 4.51	Score: 9.39
# Episode 78	Average Score: 4.59	Score: 10.13
# Episode 79	Average Score: 4.68	Score: 12.12
# Episode 80	Average Score: 4.74	Score: 9.01
# Episode 81	Average Score: 4.83	Score: 12.62
# Episode 82	Average Score: 4.91	Score: 11.03
# Episode 83	Average Score: 4.96	Score: 9.14
# Episode 84	Average Score: 5.04	Score: 11.39
# Episode 85	Average Score: 5.09	Score: 9.65
# Episode 86	Average Score: 5.16	Score: 11.33
# Episode 87	Average Score: 5.22	Score: 10.34
# Episode 88	Average Score: 5.27	Score: 9.70
# Episode 89	Average Score: 5.33	Score: 10.49
# Episode 90	Average Score: 5.39	Score: 10.45
# Episode 91	Average Score: 5.45	Score: 11.40
# Episode 92	Average Score: 5.53	Score: 12.01
# Episode 93	Average Score: 5.57	Score: 9.69
# Episode 94	Average Score: 5.62	Score: 10.47
# Episode 95	Average Score: 5.71	Score: 13.69
# Episode 96	Average Score: 5.77	Score: 11.58
# Episode 97	Average Score: 5.82	Score: 10.30
# Episode 98	Average Score: 5.90	Score: 13.70
# Episode 99	Average Score: 5.96	Score: 12.14
# Episode 100	Average Score: 6.03	Score: 13.21
# Episode 101	Average Score: 6.17	Score: 14.42
# Episode 102	Average Score: 6.29	Score: 12.13
# Episode 103	Average Score: 6.41	Score: 11.82
# Episode 104	Average Score: 6.52	Score: 12.61
# Episode 105	Average Score: 6.65	Score: 13.64
# Episode 106	Average Score: 6.79	Score: 15.17
# Episode 107	Average Score: 6.92	Score: 14.38
# Episode 108	Average Score: 7.02	Score: 11.13
# Episode 109	Average Score: 7.14	Score: 13.67
# Episode 110	Average Score: 7.27	Score: 13.91
# Episode 111	Average Score: 7.39	Score: 12.91
# Episode 112	Average Score: 7.51	Score: 13.65
# Episode 113	Average Score: 7.63	Score: 14.04
# Episode 114	Average Score: 7.77	Score: 15.12
# Episode 115	Average Score: 7.89	Score: 12.86
# Episode 116	Average Score: 8.03	Score: 14.54
# Episode 117	Average Score: 8.15	Score: 12.90
# Episode 118	Average Score: 8.28	Score: 14.05
# Episode 119	Average Score: 8.40	Score: 13.55
# Episode 120	Average Score: 8.51	Score: 12.22
# Episode 121	Average Score: 8.64	Score: 14.62
# Episode 122	Average Score: 8.76	Score: 13.22
# Episode 123	Average Score: 8.88	Score: 14.03
# Episode 124	Average Score: 9.01	Score: 14.34
# Episode 125	Average Score: 9.13	Score: 13.56
# Episode 126	Average Score: 9.26	Score: 15.01
# Episode 127	Average Score: 9.37	Score: 12.84
# Episode 128	Average Score: 9.50	Score: 14.81
# Episode 129	Average Score: 9.61	Score: 13.64
# Episode 130	Average Score: 9.73	Score: 15.35
# Episode 131	Average Score: 9.88	Score: 17.05
# Episode 132	Average Score: 10.01	Score: 15.97
# Episode 133	Average Score: 10.16	Score: 16.75
# Episode 134	Average Score: 10.30	Score: 16.48
# Episode 135	Average Score: 10.44	Score: 17.43
# Episode 136	Average Score: 10.61	Score: 20.36
# Episode 137	Average Score: 10.75	Score: 17.20
# Episode 138	Average Score: 10.87	Score: 16.64
# Episode 139	Average Score: 11.04	Score: 20.15
# Episode 140	Average Score: 11.17	Score: 17.20
# Episode 141	Average Score: 11.30	Score: 16.89
# Episode 142	Average Score: 11.44	Score: 17.44
# Episode 143	Average Score: 11.58	Score: 18.30
# Episode 144	Average Score: 11.71	Score: 17.63
# Episode 145	Average Score: 11.86	Score: 18.51
# Episode 146	Average Score: 11.99	Score: 17.81
# Episode 147	Average Score: 12.12	Score: 18.13
# Episode 148	Average Score: 12.21	Score: 13.86
# Episode 149	Average Score: 12.30	Score: 15.30
# Episode 150	Average Score: 12.42	Score: 17.39
# Episode 151	Average Score: 12.55	Score: 18.39
# Episode 152	Average Score: 12.67	Score: 18.06
# Episode 153	Average Score: 12.78	Score: 18.05
# Episode 154	Average Score: 12.90	Score: 19.62
# Episode 155	Average Score: 13.02	Score: 19.34
# Episode 156	Average Score: 13.14	Score: 20.27
# Episode 157	Average Score: 13.26	Score: 19.08
# Episode 158	Average Score: 13.42	Score: 22.42
# Episode 159	Average Score: 13.57	Score: 23.64
# Episode 160	Average Score: 13.69	Score: 19.94
# Episode 161	Average Score: 13.84	Score: 22.67
# Episode 162	Average Score: 13.98	Score: 22.54
# Episode 163	Average Score: 14.13	Score: 23.34
# Episode 164	Average Score: 14.26	Score: 22.47
# Episode 165	Average Score: 14.41	Score: 23.61
# Episode 166	Average Score: 14.57	Score: 24.50
# Episode 167	Average Score: 14.75	Score: 27.19
# Episode 168	Average Score: 14.89	Score: 23.27
# Episode 169	Average Score: 15.04	Score: 24.88
# Episode 170	Average Score: 15.17	Score: 24.42
# Episode 171	Average Score: 15.34	Score: 25.96
# Episode 172	Average Score: 15.52	Score: 26.92
# Episode 173	Average Score: 15.70	Score: 26.85
# Episode 174	Average Score: 15.87	Score: 27.31
# Episode 175	Average Score: 16.02	Score: 25.99
# Episode 176	Average Score: 16.16	Score: 23.19
# Episode 177	Average Score: 16.33	Score: 26.83
# Episode 178	Average Score: 16.50	Score: 27.04
# Episode 179	Average Score: 16.65	Score: 27.37
# Episode 180	Average Score: 16.83	Score: 26.97
# Episode 181	Average Score: 16.98	Score: 27.42
# Episode 182	Average Score: 17.15	Score: 28.49
# Episode 183	Average Score: 17.32	Score: 26.05
# Episode 184	Average Score: 17.48	Score: 27.49
# Episode 185	Average Score: 17.66	Score: 27.08
# Episode 186	Average Score: 17.83	Score: 28.06
# Episode 187	Average Score: 18.00	Score: 27.83
# Episode 188	Average Score: 18.23	Score: 32.87
# Episode 189	Average Score: 18.45	Score: 31.99
# Episode 190	Average Score: 18.65	Score: 30.51
# Episode 191	Average Score: 18.84	Score: 30.91
# Episode 192	Average Score: 19.02	Score: 29.45
# Episode 193	Average Score: 19.23	Score: 31.19
# Episode 194	Average Score: 19.45	Score: 32.44
# Episode 195	Average Score: 19.64	Score: 32.92
# Episode 196	Average Score: 19.85	Score: 32.34
# Episode 197	Average Score: 20.09	Score: 33.85
# Episode 198	Average Score: 20.29	Score: 34.15
# Episode 199	Average Score: 20.52	Score: 35.14
# Episode 200	Average Score: 20.73	Score: 34.40
# Episode 201	Average Score: 20.96	Score: 37.10
# Episode 202	Average Score: 21.20	Score: 36.43
# Episode 203	Average Score: 21.44	Score: 35.84
# Episode 204	Average Score: 21.68	Score: 35.93
# Episode 205	Average Score: 21.90	Score: 36.12
# Episode 206	Average Score: 22.12	Score: 36.87
# Episode 207	Average Score: 22.34	Score: 36.14
# Episode 208	Average Score: 22.59	Score: 36.89
# Episode 209	Average Score: 22.80	Score: 34.64
# Episode 210	Average Score: 23.02	Score: 35.51
# Episode 211	Average Score: 23.24	Score: 35.23
# Episode 212	Average Score: 23.46	Score: 35.84
# Episode 213	Average Score: 23.69	Score: 36.93
# Episode 214	Average Score: 23.91	Score: 36.95
# Episode 215	Average Score: 24.13	Score: 34.90
# Episode 216	Average Score: 24.34	Score: 35.30
# Episode 217	Average Score: 24.57	Score: 36.18
# Episode 218	Average Score: 24.77	Score: 33.56
# Episode 219	Average Score: 24.99	Score: 36.12
# Episode 220	Average Score: 25.23	Score: 35.97
# Episode 221	Average Score: 25.45	Score: 36.23
# Episode 222	Average Score: 25.68	Score: 36.43
# Episode 223	Average Score: 25.91	Score: 37.11
# Episode 224	Average Score: 26.13	Score: 36.07
# Episode 225	Average Score: 26.35	Score: 36.13
# Episode 226	Average Score: 26.56	Score: 35.96
# Episode 227	Average Score: 26.80	Score: 36.13
# Episode 228	Average Score: 27.01	Score: 36.01
# Episode 229	Average Score: 27.24	Score: 36.90
# Episode 230	Average Score: 27.45	Score: 36.22
# Episode 231	Average Score: 27.64	Score: 36.06
# Episode 232	Average Score: 27.84	Score: 36.51
# Episode 233	Average Score: 28.05	Score: 37.18
# Episode 234	Average Score: 28.26	Score: 37.15
# Episode 235	Average Score: 28.45	Score: 37.33
# Episode 236	Average Score: 28.63	Score: 38.00
# Episode 237	Average Score: 28.82	Score: 36.24
# Episode 238	Average Score: 29.04	Score: 38.04
# Episode 239	Average Score: 29.19	Score: 35.45
# Episode 240	Average Score: 29.39	Score: 37.12
# Episode 241	Average Score: 29.57	Score: 35.16
# Episode 242	Average Score: 29.76	Score: 36.71
# Episode 243	Average Score: 29.95	Score: 36.78
# solvede 244	Average Score: 30.15	Score: 38.08
